# %%
import lancedb
from dotenv import load_dotenv

load_dotenv()

db = lancedb.connect(uri = "../knowledge_base")
db
# Out:
# LanceDBConnection(uri='/Users/aigineer/Documents/github/RAG_mlops25/rag/src/rag/explorations/../knowledge_base')

# %%
db["articles"]
# Out:
# LanceTable(name='articles', version=12, _conn=LanceDBConnection(uri='/Users/aigineer/Documents/github/RAG_mlops25/rag/src/rag/explorations/../knowledge_base'))

# %%
db["articles"].to_pandas()
# Out:
#   document_name                                           filepath  \
# 0     tiger.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 1     panda.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 2     kanin.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 3    krabba.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 4      fisk.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
#
#                                              content  \
# 0  Tiger (Panthera tigris) är ett kattdjur som en...
# 1  Jättepanda (Ailuropoda melanoleuca), panda, pa...
# 2  Harar och kaniner\n\nArtikel\nDiskussion\nLäs\...
# 3  Krabbor (Brachyura) är en delordning av vatten...
# 4  Fiskar (Pisces) är en grupp vattenlevande rygg...
#
#                                            embedding
# 0  [0.022979736, 0.03173828, -0.004386902, -0.050...
# 1  [0.07891846, 0.018447876, -0.00818634, -0.0604...
# 2  [-0.021530151, -0.024368286, 0.004486084, -0.0...
# 3  [0.011001587, -0.032714844, -0.049072266, -0.0...
# 4  [0.05697632, 0.020736694, -0.028640747, -0.049...

# %%
db["articles"].search("vad äter pandor?").to_pandas()
# Out:
#   document_name                                           filepath  \
# 0     panda.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 1    krabba.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 2     tiger.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 3      fisk.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
# 4     kanin.txt  /Users/aigineer/Documents/github/RAG_mlops25/r...
#
#                                              content  \
# 0  Jättepanda (Ailuropoda melanoleuca), panda, pa...
# 1  Krabbor (Brachyura) är en delordning av vatten...
# 2  Tiger (Panthera tigris) är ett kattdjur som en...
# 3  Fiskar (Pisces) är en grupp vattenlevande rygg...
# 4  Harar och kaniner\n\nArtikel\nDiskussion\nLäs\...
#
#                                            embedding  _distance
# 0  [0.07891846, 0.018447876, -0.00818634, -0.0604...   0.805973
# 1  [0.011001587, -0.032714844, -0.049072266, -0.0...   0.968146
# 2  [0.022979736, 0.03173828, -0.004386902, -0.050...   0.989740
# 3  [0.05697632, 0.020736694, -0.028640747, -0.049...   1.145316
# 4  [-0.021530151, -0.024368286, 0.004486084, -0.0...   1.200752
